# %%
# Initialize Otter
import otter
grader = otter.Notebook("homework-00.ipynb")

# %% [markdown]
# # Stat 316: Homework 0 (Class Survey)
#
# Write your Name here
#
# ## Class Survey
#
# Please answer the following questions. Write your answer to each
# question below the question.
#
# 1.  Your name?
#
# 2.  Your major?
#
# 3.  What math classes have you taken?
#
# 4.  What programming languages do you know?
#
# 5.  What do you hope to learn from this class?

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(run_tests=True)
