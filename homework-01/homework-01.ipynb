# %% [markdown]
# # Stat 316: Homework 1
#
# Write your Name here
#
# ## Homework 1
#
# ### Exercise 1.4
#
# ### Exercise 1.7
#
# ### Exercise 1.8
#
# ### Exercise 1.14
#
# ### Run other code
#
# #### prog1.R
#
# Some R commands

# %%
z <- c(5,4,8,12,10,20,25,27,14,80)
z
# Out:
#  [1]  5  4  8 12 10 20 25 27 14 80
#  [1] 10  9 13 17 15 25 30 32 19 85
# [1] 13 17 15 25 30 32 19 85
# [1] 10
# [1] 0.8
# [1] 25.5
# [1] 499.6111
# [1] 22.35198
# [1] 18
# 50%
#  18

# %% [markdown]
# #### prog2.R
#
# #### prog3.R
#
# #### prog4.R
#
# #### prog5.R
#
# #### prog6.R
